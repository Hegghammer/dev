# %% [markdown]
# # Our first Jupyter notebook

# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt 
x = [1,2,3] 
y = [2,4,1] 
plt.plot(x, y) 
plt.title('Our first graph') 
plt.show()
